# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../data/machine_data.csv")
df.head()

# %%
df.head()

# %%
print("Rows and Columns:", df.shape)

# %%
df.info()

# %%
df.describe()

# %%
print(df.isnull().sum())

# %%
print("Duplicate Rows:", df.duplicated().sum())

# %%
print(df["Status"].unique())

# %%
print(df["Status"].value_counts())

# %%
encoder = LabelEncoder()

df["Status"] = encoder.fit_transform(df["Status"])

df.head()

# %%
print(df.corr())

# %%
plt.figure(figsize=(6,4))

plt.hist(df["Temperature"], bins=10)

plt.title("Temperature Distribution")

plt.xlabel("Temperature")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df["Vibration"], bins=10)

plt.title("Vibration Distribution")

plt.xlabel("Vibration")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df["Current"], bins=10)

plt.title("Motor Current Distribution")

plt.xlabel("Current")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df["RPM"], bins=10)

plt.title("RPM Distribution")

plt.xlabel("RPM")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.scatter(df["Temperature"], df["Status"])

plt.title("Temperature vs Machine Status")

plt.xlabel("Temperature")

plt.ylabel("Status")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.scatter(df["Vibration"], df["Status"])

plt.title("Vibration vs Machine Status")

plt.xlabel("Vibration")

plt.ylabel("Status")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.scatter(df["Current"], df["Status"])

plt.title("Current vs Machine Status")

plt.xlabel("Current")

plt.ylabel("Status")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.scatter(df["RPM"], df["Status"])

plt.title("RPM vs Machine Status")

plt.xlabel("RPM")

plt.ylabel("Status")

plt.show()

# %%
df.head()
